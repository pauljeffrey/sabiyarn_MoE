# %%
len("""
  The most defining experience of my career occurred during the development of SabiYarn, Nigeria's first foundational language model—a project that tested every aspect of my resilience, leadership, and adaptability while creating unprecedented impact for African language preservation and technological advancement.

When I initiated this project in late 2023, skepticism was overwhelming. Colleagues questioned whether a resource-limited environment could produce competitive AI models, especially given the computational costs and technical complexity involved. The challenge seemed insurmountable: developing a foundational model for eight Nigerian languages with limited funding, computational resources, and a small team of volunteers.

**Demonstrating Resilience:** The project faced numerous setbacks. Our initial training runs failed due to data quality issues, computational limitations forced us to restart multiple times, and team members occasionally lost motivation. During one particularly challenging period, we lost three weeks of training progress due to infrastructure failures. Rather than abandoning the project, I restructured our approach, implementing incremental checkpointing systems and developing cost-effective training strategies inspired by recent research breakthroughs.

**Exercising Leadership:** Leading a distributed team of linguists, engineers, and data scientists across different time zones required adaptive leadership. I established clear communication protocols, created milestone-based motivation systems, and fostered a collaborative environment where each team member's expertise was valued. When technical disagreements arose, I facilitated knowledge-sharing sessions that transformed conflicts into learning opportunities. My medical background helped me approach problems systematically, while my AI expertise enabled me to make informed technical decisions under pressure.

**Adapting to Constraints:** Limited computational resources forced innovative solutions. I researched and implemented cutting-edge efficiency techniques, optimized our training pipeline for cost-effectiveness, and negotiated partnerships with local tech companies for computational support. This adaptability not only saved the project but also resulted in a more efficient model architecture.

**Community Impact:** SabiYarn's success created ripple effects across Africa's tech ecosystem. The model's superior performance on Nigerian language tasks (outperforming GPT-4 by 48% and LLaMA2-13B by 259%) demonstrated that locally-developed AI could excel in culturally-specific contexts. This breakthrough inspired similar initiatives across Africa, with researchers from Ghana, Kenya, and South Africa reaching out for collaboration. The project also contributed to preserving endangered Nigerian languages by creating digital representations that future generations can access.

**Personal and Professional Growth:** This experience transformed my understanding of leadership under constraints. I learned that resilience isn't just about persevering through difficulties—it's about finding innovative solutions that turn limitations into advantages. The project taught me to balance technical excellence with team motivation, manage distributed collaborations effectively, and communicate complex technical concepts to diverse stakeholders.

**Preparation for Graduate Studies:** Managing SabiYarn's complexity—from technical architecture decisions to team coordination—prepared me for the interdisciplinary challenges of graduate research. The experience demonstrated my ability to lead ambitious projects, adapt to resource constraints, and create meaningful impact despite obstacles.

This journey reinforced my commitment to developing technologies that serve underrepresented communities, preparing me to tackle the complex challenges I'll encounter in robotics and biomedical engineering research.Through this program, I will not only advance my technical capabilities but also develop the leadership skills necessary to drive meaningful change in global healthcare accessibility and quality.
""".split())
# Out:
# 509

# %%
#!pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
#!pip install triton transformers einops

# %%
# !pip install -q tiktoken datasets==2.14.5 omegaconf 
#deepspeed accelerate==0.23 bitsandbytes einops
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -q --upgrade huggingface_hub
# !pip install -U -q "huggingface_hub[cli]"
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# !huggingface-cli login --token "$HF_API_KEY" #Read token, set via .env / environment

# %% [markdown]
# ## Finetuning Tokenizer

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import HfApi

load_dotenv()
HF_WRITE_TOKEN = os.environ.get("HF_WRITE_TOKEN") or os.environ.get("HF_API_KEY")
HF_READ_TOKEN = os.environ.get("HF_API_KEY")

api = HfApi(token=HF_WRITE_TOKEN)

# %%
from datasets import load_dataset, concatenate_datasets
from omegaconf import OmegaConf
import os

config_path = "../config/config.yaml" #os.path.join(project_root, "config", "config.yaml")
config = OmegaConf.load(config_path)

# repo_names = config.data.datasets # For main tokenizer training
repo_names = ["Aletheia-ng/pretrain_test"]

all_datasets = []

for repo_name in repo_names:
    dataset = load_dataset(repo_name, token=HF_READ_TOKEN)
    all_datasets.append(dataset["train"])

# Concatenate all datasets
dataset = concatenate_datasets(all_datasets)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 14
#      11 all_datasets = []
#      13 for repo_name in repo_names:
# ---> 14     dataset = load_dataset(repo_name, token=HF_READ_TOKEN)
#      15     all_datasets.append(dataset["train"])
#      17 # Concatenate all datasets
#
# File c:\Users\Jeffrey Paul\AppData\Local\Programs\Python\Python313\Lib\site-packages\datasets\load.py:2129, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2124 verification_mode = VerificationMode(
#    2125     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2126 )
# ...

# %%
batch_size = 5000
def get_training_corpus1():
    return (
        dataset[i : i + batch_size]["text"]
        for i in range(0, len(dataset["train"]), batch_size)
    )


def get_training_corpus():
    train_dataset = dataset
    for start_idx in range(0, len(train_dataset), batch_size):
        samples = train_dataset[start_idx : start_idx + batch_size]
        yield samples["text"]

training_corpus = get_training_corpus()

# %% [markdown]
# Use the tokenizer you want (sentencepiece tokenizer)

# %%
from transformers import AutoTokenizer, BloomTokenizerFast, GemmaTokenizerFast, LlamaTokenizerFast

# tokenizer = BloomTokenizerFast.from_pretrained("bigscience/bloom")
tokenizer = LlamaTokenizerFast.from_pretrained("meta-llama/Meta-Llama-3-8B", token=HF_READ_TOKEN) #I am not certain LLama uses sentence piece

#if it doesnt, fetch all special tokens (most open source datasets have llama's structure)
all_special_tokens = tokenizer.all_special_tokens_extended
print(all_special_tokens)

# Comment out if llama uses sentencepiece indeed
# tokenizer = GemmaTokenizerFast.from_pretrained("google/gemma-2-2b", token= HF_READ_TOKEN) # Uses sentence piece, tokenizerFast for fast batch processing
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'PreTrainedTokenizerFast'.
# The class this function is called from is 'LlamaTokenizerFast'.
# [AddedToken("<|begin_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True), AddedToken("<|end_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True), '<unk>']

# %%
all_special_tokens
# Out:
# [AddedToken("<|begin_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  AddedToken("<|end_of_text|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  '<unk>']

# %%
#Add all llama special tokens
#all_special_tokens +
special_tokens =  ["O", "B-PER", "I-PER", "B-ORG", "I-ORG", "B-LOC", "I-LOC", "B-DATE", "I-DATE",
    "<context>", "<lug>", "<qa>", "<tsn>", "<afr>", "<identify>", "<fuv>", "<reason>", "<din>", "<xsm>", "<zu>", "<tmh>", 
    "<ti>", "<tzm>", "<ny>", "<arb>", "<correct>", "<dyu>", "<eng>", "<kea>", "<fra>", "<score>", "<kab>", "<amh>", "<toxic>", "<pcm>",
    "<response>", "<hau>", "<swh>", "<snq>", "<translate>", "<ful>", "<prompt>", "<ton>", "<vag>", "<nup>", "<kmb>", "<mey>", "<classify>",
    "<text>", "<luo>", "<sn>", "<nus>", "<ven>", "<oke>", "<yor>", "<sentiment>", "<headline>", "<xh>", "<son>", "<igl>", "<kik>", 
    "<clean>", "<wolof>", "<sag>", "<aku>", "<tso>", "<ewe>", "<ngl>", "<run>", "<lang_ID>", "<gah>", "<bm>", "<kbp>", "<STR>", "<umb>",
    "<aka>", "<lin>", "<urh>", "<tum>", "<nso>", "<ssw>", "<topic>", "<title>", "<fat>", "<som>", "<vai>", "<tag>", "<sot>", "<mos>", 
    "<tiv>", "<kon>", "<diacritize>", "<fon>", "<twi>", "<nde>", "<NER>", "<bem>", "<knc>", "<nya>", "<orm>", "<oro>", "<mlg>", "<shi>", "<|end_of_text|>",
    "<summarize>", "<lus>", "<gaa>", "<ibo>", "<ibb>", "<kin>", "<mzw>", "<kam>","<question>", "<summary>", "<answer>","<ner>", "<intent>", "<lang_ID_label>"]

# %%
new_tokenizer = tokenizer.train_new_from_iterator(training_corpus, 64000 , new_special_tokens=special_tokens)

# %%
new_tokenizer.save_pretrained("sabiyarn-tokenizer")

# Change the repo to a temporary one if you are testing the model
# new_tokenizer.push_to_hub("Aletheia-ng/SabiYarnV2", token=HF_WRITE_TOKEN)

new_tokenizer.push_to_hub("Aletheia-ng/SabiYarn_test", token=HF_WRITE_TOKEN)

# %% [markdown]
# ## Test Tokenizer

# %%
prompt_template = "[INST] <<SYS>> You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe.  \
Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and \
positive in nature. If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer \
to a question, please don't share false information.<</SYS>> \
{}[/INST]"

prompt = prompt_template.format(" who is elon musk?")

# %%
from transformers import AutoTokenizer
import transformers
import torch

tokenizer_path = "sabiyarn-tokenizer"
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path, use_fast=False)


prompt = "Describe a painting of a falcon in a very detailed way." # Change this to your prompt
prompt_template = f"### Instruction: {prompt}\n### Response:"

tokens = tokenizer(prompt_template, return_tensors="pt").input_ids

print("Length of processed tokens: ", len(tokens[0]))
print("Decoded tokens: ", tokenizer.decode(tokens))

# %% [markdown]
# ## Counting the Number of Pretraining Tokens

# %%
def num_tokens_from_string(string: str, encoding_name: str = "gpt-3.5-turbo") -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.encoding_for_model(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
from nltk.tokenize import sent_tokenize
import tiktoken

gpt_used = "gpt-4.1"
n_tokens = []
n_sentences = []
sabiyarn_n_tokens = []
sabiyarn_parent_n_tokens = []
 
for each in dataset["train"]:
    #print(each)
    n_tokens.append(num_tokens_from_string(str(each["text"]), gpt_used))
    sabiyarn_n_tokens.append(len(new_tokenizer.encode(str(each["text"]))))
    sabiyarn_parent_n_tokens.append(len(tokenizer.encode(str(each['text']))))
    n_sentences.append(len(sent_tokenize(str(each['text']))))

# %%
import pandas as pd
df = pd.DataFrame({f"{gpt_used} tokenizer": n_tokens, "sabiyarn tokenizer": sabiyarn_n_tokens, "parent tokenizer": sabiyarn_parent_n_tokens, 
                   "number of sentences": n_sentences})

df.to_csv("pretraining_data_sample_token_length.csv")

# %%
# df = pd.read_csv('pretraining_data_sample_token_length.csv')
# df.head()
