# %%
# lang_id_token = 26290
# lang_id_label_token = 102
# classify_token = 42303
# sentiment_token = 13896
# topic_token = 49704
# ner_token = 30827
# qa_token = 23846
# answer_token = 47682
# tag_token = 7203
# diacritize_token = 19588
# correct_token = 48220
# clean_token = 31666
# summarize_token = 114
# summary_token = 16150
# title_token = 27246
# headline_token = 49296
# end_of_token = 14004
# translate_token = 34635
# # classify_token = 5
# ner_token = 30827
# eng = 1516
# yor = 40754
# ibo = 26762
# hau = 13679
# pcm = 28112
# prompt = 37160
# response = 2474
# MASK = -100

# %%
import os
os.chdir("..")

# %%
# !pip install triton
# Out:
# ERROR: Could not find a version that satisfies the requirement triton (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for triton

# %%
import torch
from sabiyarn.model import *

vocab_size = 64000
# Test 8: Distributed Training Config
def load_model():       
    mla_config = MLAConfig(
        hidden_size=256, num_heads=8, max_seq_len=32, max_batch_size=2,
        attention_dropout=0.0, q_lora_rank=64, qk_rope_head_dim=16,
        kv_lora_rank=32, v_head_dim=32, qk_nope_head_dim=16,
        attention_bias=False, original_seq_len=32, rope_theta=10000.0,
        rope_factor=1, beta_fast=32, beta_slow=1, mscale=1.
    )
    config_mla = ModelArgs(
        dim=256, n_layers=1, n_heads=8, vocab_size=vocab_size,
        attention_type=AttentionType.MLA, mla_config=mla_config,
        auto_detect_distributed=True
    )
    model_mla = SabiYarn(config_mla)
    model_mla.eval()
    
    print("✅ Distributed training configuration test passed!")
    return model_mla

model = load_model()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import torch
# ----> 2 from sabiyarn.model import *
#       4 vocab_size = 64000
#       5 # Test 8: Distributed Training Config
#
# File c:\Users\Jeffrey Paul\Desktop\AI work\AI projects\sabiyarn\sabiyarn\__init__.py:1
# ----> 1 from .model import ModelArgs, SabiYarn
#       3 # Optional imports that might have dependencies
#       4 try:
#
# File c:\Users\Jeffrey Paul\Desktop\AI work\AI projects\sabiyarn\sabiyarn\model.py:14
#      12 from .memory_reasoning import LogicNetwork
#      13 from .differential_attention import DiffAttention, DiffAttnArgs
# ---> 14 from .MLA import MLA, MLAConfig, ColumnParallelLinear, RowParallelLinear, linear
#      15 from .MHA import SelfAttention, SelfAttnArgs, precompute_freqs_cis
#      18 class AttentionType(str, Enum):
#
# File c:\Users\Jeffrey Paul\Desktop\AI work\AI projects\sabiyarn\sabiyarn\MLA.py:10
#       8 from dataclasses import dataclass
#       9 from typing import Tuple, Optional, Literal
# ---> 10 from .kernel import act_quant, weight_dequant, fp8_gemm
#      11 import math
#      13 world_size = 1 # the number of GPUs
#
# File c:\Users\Jeffrey Paul\Desktop\AI work\AI projects\sabiyarn\sabiyarn\kernel.py:4
#       1 from typing import Tuple
#       3 import torch
# ----> 4 import triton
#       5 import triton.language as tl
#       6 from triton import Config
#
# ModuleNotFoundError: No module named 'triton'

# %%
def generate_random_tokens(batch_size, seq_len, vocab_size=1000):
    return torch.randint(0, vocab_size, (batch_size, seq_len))

tokens = generate_random_tokens(1, 2048, vocab_size)

# %%
with torch.no_grad():
        tokens = torch.randint(0, 1000, (1, 8))
        hidden_states, logits = model(tokens, max_new_tokens=4096, temperature=1.0, top_k=None, use_multi_token=False)
